# %%
import pandas as pd
dummied_listings = pd.read_csv('dummied_listing_df.csv')
pd.set_option('display.max_columns', None)
dummied_listings.describe()
# Out:
#              price  accommodates    bathrooms     bedrooms         beds  \
# count  3818.000000   3818.000000  3818.000000  3818.000000  3818.000000
# mean    127.976166      3.349398     1.259469     1.307712     1.735394
# std      90.250022      1.977599     0.589130     0.882700     1.139330
# min      20.000000      1.000000     0.000000     0.000000     1.000000
# 25%      75.000000      2.000000     1.000000     1.000000     1.000000
# 50%     100.000000      3.000000     1.000000     1.000000     1.000000
# 75%     150.000000      4.000000     1.000000     2.000000     2.000000
# max    1000.000000     16.000000     8.000000     7.000000    15.000000
#
#                 TV     Cable TV     Internet  Wireless Internet  \
# count  3818.000000  3818.000000  3818.000000        3818.000000
# mean      0.674175     0.378732     0.736249           0.960450
# std       0.468744     0.485135     0.440723           0.194924
# ...
